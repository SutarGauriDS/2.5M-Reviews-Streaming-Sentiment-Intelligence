# %%
# %sql
CREATE OR REPLACE VIEW streaming_sentiment_intelligence.default.vw_powerbi_sentiment
AS
SELECT
    sentiment,
    total_reviews,
    avg_likes,
    avg_retweets,
    avg_engagement,
    avg_text_length,
    avg_word_count
FROM streaming_sentiment_intelligence.default.gold_sentiment_summary;

# %%
# %sql
SELECT *
FROM streaming_sentiment_intelligence.default.vw_powerbi_sentiment;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql
CREATE OR REPLACE VIEW streaming_sentiment_intelligence.default.vw_powerbi_platform
AS
SELECT
    platform,
    sentiment,
    review_count,
    avg_likes,
    avg_retweets,
    avg_engagement
FROM streaming_sentiment_intelligence.default.gold_platform_analysis;

# %%
# %sql
CREATE OR REPLACE VIEW streaming_sentiment_intelligence.default.vw_powerbi_country
AS
SELECT
    country,
    sentiment,
    review_count,
    avg_likes,
    avg_retweets,
    avg_engagement
FROM streaming_sentiment_intelligence.default.gold_country_analysis;

# %%
# %sql
CREATE OR REPLACE VIEW streaming_sentiment_intelligence.default.vw_powerbi_country
AS
SELECT
    country,
    sentiment,
    review_count,
    avg_likes,
    avg_retweets,
    avg_engagement
FROM streaming_sentiment_intelligence.default.gold_country_analysis;

# %%
# %sql
CREATE OR REPLACE VIEW streaming_sentiment_intelligence.default.vw_powerbi_time
AS
SELECT
    year,
    month,
    day,
    hour,
    sentiment,
    review_count,
    avg_likes,
    avg_retweets,
    avg_engagement
FROM streaming_sentiment_intelligence.default.gold_time_analysis;
